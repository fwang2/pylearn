# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np

# %%
x = np.linspace(-5, 5)
y = (x+2)**2 + (x-3)**3

plt.plot(x, y, linewidth=4, )
plt.axhline(0, c='gray')
plt.axvline(0, c='gray')
